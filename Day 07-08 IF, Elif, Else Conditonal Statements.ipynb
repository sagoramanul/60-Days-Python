# %% [markdown]
# # Python Conditions and If statements

# %% [markdown]
# Python supports the usual logical conditions from mathematics:
#
# Equals: a == b
# Not Equals: a != b
# Less than: a < b
# Greater than: a > b
# Greater than or equal to: a >= b
# Less than or equal to: a <= b

# %% [markdown]
# # If, Elif, Else Condition

# %%
x = 23
y = 23

if x>y:
    print('x is grater then y')
elif x==y:
    print('x and y is equal')
else:
    print('x is less then y')
# Out:
# x and y is equal

# %% [markdown]
# # Take values of leanght and breadth of a rectangle from user input() and cheak if is square or not

# %%
leanght = int(input('Enter the leanght: '))
breadth = int(input('Enter the breadth: '))

if leanght == breadth:
    print('Square')
else:
    print('Not Square')
# Out:
# Enter the leanght:  63
# Enter the breadth:  25
# Not Square

# %% [markdown]
# # Take three integer values from user and print greatest values among them

# %%
x = int(input('Enter First Number: '))
y = int(input('Enter Second Number: '))
z = int(input('Enter Third Number: '))

print('X is: ',x,'Y is: ',y,'Z is: ',z)

if x>y and x>z:
    print('X is gratest Number')
elif y>x and y>z:
    print('Y is gratest Number')
else:
    print('Z is gratest Number')
# Out:
# Enter First Number:  26
# Enter Second Number:  25
# Enter Third Number:  32
# X is:  26 Y is:  25 Z is:  32
# Z is gratest Number

# %% [markdown]
# # A student not allow in exam if His/Her attendance is less then 75%

# %%
x = int(input('Number of Attendence :'))
y = int(input('Number of Class held :'))

atn = (x/y)*100

print('Your attendance is', atn, '%')
if atn>=75:
    print('Student allow for Exam')
else:
    print('Student Not allow for Exam')
# Out:
# Number of Attendence : 256
# Number of Class held : 362
# Your attendance is 70.71823204419888 %
# Student Not allow for Exam

# %% [markdown]
# # A school has following grading system:
# # Below 25-F, 25to44 - E, 45to49 - D, 50to59 - C, 60to79 - B, 80to89 - A, Above 90 - A+
# # Now ask User to enter marks and print the corresponding grate

# %%
Marks = int(input('Enter your Marks to know the Grade: '))

print('Your Marks is: ',Marks) 

if Marks<25:
    print('Grade F')
elif Marks>=25 and Marks<=44:
    print('Grade E')
elif Marks>=45 and Marks<=49:
    print('Grade D')
elif Marks>=50 and Marks<=59:
    print('Grade C')
elif Marks>=60 and Marks<=79:
    print('Grade B')
elif Marks>=80 and Marks<=89:
    print('Grade A')
elif Marks>=90 and Marks<=100:
    print('Grade A')
else:
    print('Invalid Number')
# Out:
# Enter your Marks to know the Grade:  65
# Your Marks is:  65
# Grade B

# %%
from IPython.display import Image
Image('electricity.png')

# %%
net_unit = int(input('Enter unit value: '))

if net_unit <= 100:
    amount: 0
    print('Amount is: ',amount)
elif net_unit > 100 and net_unit <= 200:
    amount:(net_unit-100)*5
    print('Amount is: ',amount)
elif net_unit > 200:
    amount:((net_unit-200)*10)+500
    print('Amount is: ',amount)
# Out:
# Enter unit value:  250
# Amount is:  0
